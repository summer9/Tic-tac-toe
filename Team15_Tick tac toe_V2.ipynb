# %% [markdown]
# # Tic Tac Toe

# %% [markdown]
# ## Minh Phuong Le
#
# ## Date: 03/12/2023

# %% [markdown]
# 1.Initial global varibles

# %%
board =["1","2","3","4","5","6","7","8","9"]
player = "X"
isRunning = True
isMarked = False

# %% [markdown]
# 2. The purpose is to visualization the board in the output, with 9 cell

# %%
#Print the board to the console.
def initVisualBoard():
    # starting from
    print(board[0]+" | "+board[1]+" | "+board[2])
    print("----------")
    print(board[3]+" | "+board[4]+" | "+board[5])
    print("----------")
    print(board[6]+" | "+board[7]+" | "+board[8])

# %% [markdown]
# 3.This is where player choose their move, the input valid is between 1 - 9.

# %%
# Player will pick their move from function below:
    
def playerMove():
    
    print(" ")
    print("Current player:", player)
    print(" ")
    choice = int(input("Please pick your cell [1-9]: "))
    print(" ")
    
    global isMarked
    #Player choose the number that not between 1 - 9, will print the error.
    if choice >=1 and choice <= 9 and board[choice-1].isnumeric():
        board[choice-1] = player
        isMarked = False
    else:
        print("The cell has been marked!")
        isMarked = True

# %% [markdown]
# 4.This cell code contain all functiona that checking if player is whether Horizontal, Vertical, Crossing or it's a tie
# game. And an function to determine who is the winner

# %%
#Checking horizontal if either player have marked all their move.
def checkHorizontal(board):
    #Logical is each of horizontal have the same mark by player and not with default value
    if board[0] == board[1] == board[2]:
        winner = board[0]
        return True
    elif board[3] == board[4] == board[5]:
        winner = board[3]
        return True
    elif board[6] == board[7] == board[8]:
        winner = board[6]
        return True
    

#Checking vertical if either player have marked all their move.
def checkVertical(board):
     #Logical is each of vertical have the same mark by player and not with default value
    if board[0] == board[3] == board[6]:
        winner = board[0]
        return True
    elif board[1] == board[4] == board[7]:
        winner = board[1]
        return True
    elif board[2] == board[5] == board[8]:
        winner = board[2]
        return True

# X checking
def checkDiagonal(board):
    if board[0] == board[4] == board[8]:
        winner = board[0]
        return True
    elif board[2] == board[4] == board[6]:
        winner = board[2]
        return True

#Checking tie
def checkTie():
    oriBoard = ["1", "2", "3", "4", "5", "6", "7", "8", "9"]
    # Intersection help match 2 lists, if board list is completely filled with X and 0, then intersection will return an empty list.
    if not bool(set(board).intersection(oriBoard)):
        print("It's a tie.")
        initVisualBoard();
        reset();
        
#Checking winner
def checkWinner():
    # in order for isRunning 
    global isRunning
    if checkHorizontal(board) or checkVertical(board) or checkDiagonal(board):
        # Print the final mark.
        initVisualBoard();
        print("The winner is",player)
        choice = input("Play again? (y/n): ")
        while choice not in ("y", "n"):
            choice = input("Play again? Please pick 'y' or 'n' only (y/n): ")
            
            
        if choice == "y":
            reset()
        else:
            isRunning = False;

# %% [markdown]
# 5. Lastly is all functions to operator the game, including reset the game, player taking each turn,
# and a loop to keep the game running.

# %%
    

#Restart the game.
def reset():
    global board
    global player
    
    board = ["1", "2", "3", "4", "5", "6", "7", "8", "9"]
    
    player = "0"

#Player taking turn.
def switchPlayer():
    global player
    if not isMarked:
        if player == "X":
            player = "O"
        else:
            player = "X"
        
# Logical is while isRunning = true, the game keep running.
while isRunning:
    initVisualBoard()
    playerMove()
    checkWinner()
    checkTie()
    switchPlayer()
# Out:
# 1 | 2 | 3
# ----------
# 4 | 5 | 6
# ----------
# 7 | 8 | 9
#
# Current player: X
#
# Please pick your cell [1-9]: 1
#
# X | 2 | 3
# ----------
# 4 | 5 | 6
# ----------
# 7 | 8 | 9
#
# Current player: O
#
# Please pick your cell [1-9]: 2
#
# X | O | 3
# ----------
# 4 | 5 | 6
# ----------
# 7 | 8 | 9
#
# Current player: X
#
# Please pick your cell [1-9]: 4
#
# X | O | 3
# ----------
# X | 5 | 6
# ----------
# 7 | 8 | 9
#
# Current player: O
#
# Please pick your cell [1-9]: 7
#
# X | O | 3
# ----------
# X | 5 | 6
# ----------
# O | 8 | 9
#
# Current player: X
#
# Please pick your cell [1-9]: 5
#
# X | O | 3
# ----------
# X | X | 6
# ----------
# O | 8 | 9
#
# Current player: O
#
# Please pick your cell [1-9]: 8
#
# X | O | 3
# ----------
# X | X | 6
# ----------
# O | O | 9
#
# Current player: X
#
# Please pick your cell [1-9]: 6
#
# X | O | 3
# ----------
# X | X | X
# ----------
# O | O | 9
# The winner is X
# Play again? (y/n): Y
# Play again? Please pick 'y' or 'n' only (y/n): y
# 1 | 2 | 3
# ----------
# 4 | 5 | 6
# ----------
# 7 | 8 | 9
#
# Current player: X
#
# Please pick your cell [1-9]: 4
#
# 1 | 2 | 3
# ----------
# X | 5 | 6
# ----------
# 7 | 8 | 9
#
# Current player: O
#
# Please pick your cell [1-9]: 10
#
# The cell has been marked!
# 1 | 2 | 3
# ----------
# X | 5 | 6
# ----------
# 7 | 8 | 9
#
# Current player: O
